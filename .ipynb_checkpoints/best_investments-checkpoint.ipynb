# %%
import pandas as pd
import numpy as np

# %%
stock = pd.read_csv("stock_price_clean.csv")
bond = pd.read_csv("GS1.csv")
housing = pd.read_csv("house_price_clean.csv")

# %%
stock = stock[stock['Symbol'] != 'BHF']
stock = stock[stock['Symbol'] != 'MNST']

# %%
stock["date"] = pd.to_datetime(stock["Year_Month"], infer_datetime_format = True)
stock["year"] = [x.year for x in stock["date"]]

# %%
tmp = stock.groupby(['year', 'Company', "Symbol"]).sum().sum(
    level=['year', 'Company',"Symbol"]).unstack('year').fillna(0).reset_index()
stock_mean = tmp["Close"]
# Fix the column names
# df.columns = ['Date', 'one', 'two']

# %%
stock_mean["Company"] = tmp["Company"]
stock_mean["Symbol"] = tmp["Symbol"]
# Out:
# /Users/JanicaTang/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
years = list(stock_mean.columns[:-3])
std_stock = stock_mean.copy()
for i in range(len(years)):
    std_stock[years[i]] = (stock_mean[2018] - stock_mean[years[i]])/(stock_mean[years[i]])

# %%
best = pd.DataFrame(columns = columns)

# %%
best
# Out:
# Empty DataFrame
# Columns: [year, stock, stock_short, stock_price, house, house_price, rank]
# Index: []

# %%
columns = ["year", "stock", "stock_short", "stock_price", "house", "house_price", "rank"]

# %%
for i in range(len(years)):
    house_index = np.argsort(-std_house[years[i]])[0:5]
    stock_index = np.argsort(-std_stock[years[i]])[0:5]
    for j in range(5):
        h_idx = house_index[j]
        s_idx = stock_index[j]
        data = [[years[i], std_stock.iloc[s_idx]["Company"], std_stock.iloc[s_idx]["Symbol"], 
                std_stock.iloc[s_idx][years[i]], std_house.iloc[h_idx]["City"],std_house.iloc[h_idx][years[i]], j]]
        tmp_df = pd.DataFrame(data, columns = columns)
        best = best.append(tmp_df)

# %%
best["stock"] = tmp1
best["stock_short"] = tmp2

# %%
best.to_csv("optimals.csv", index = False)

# %%
# Out:
# year      1996      1997      1998      1999      2000      2001      2002  \
# 0     1.098798  0.526214  0.573574  0.544204  0.535156  0.497143  0.456905
# 1     1.522593  0.868996  0.839542  0.761317  0.698413  0.698413  0.654639
# 2     2.840830  1.690909  1.407809  1.044199  0.699847  0.479014  0.409524
# 3     1.559819  0.943445  0.910699  0.953488  0.810056  0.769111  0.769111
# 4     1.865248  1.093264  1.013289  0.920761  0.873261  0.806259  0.702247
# 5     5.203791  3.152260  2.569189  2.051282  1.473311  1.136271  0.886847
# 6     1.302632  0.652893  0.616628  0.548673  0.483051  0.447777  0.440329
# 7     1.518148  1.072091  0.809353  0.650533  0.470760  0.344021  0.229829
# 8     0.213213 -0.100223 -0.188755 -0.273381 -0.323283 -0.357711 -0.383206
# 9     1.925295  1.133843  1.040219  0.932468  0.797101  0.644805  0.567416
# 10    1.131579  0.553957  0.491369  0.422613  0.348595  0.301205  0.243762
# ...

# %%
housing["date"] = pd.to_datetime(housing["Year_Month"], infer_datetime_format = True)
housing["year"] = [x.year for x in housing["date"]]

# %%
tmp = housing.groupby(['year', 'City']).sum().sum(
    level=['year', 'City']).unstack('year').fillna(0).reset_index()

# %%
house_mean = tmp["Price"]

# %%
house_mean["City"] = tmp["City"]

# %%
house_mean[2018] = house_mean[2018]/3*12

# %%
std_house = house_mean.copy()
for i in range(len(years)):
    std_house[years[i]] = (house_mean[2018] - house_mean[years[i]])/(house_mean[years[i]])

# %%
# std_house
